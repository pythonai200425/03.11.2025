# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %% [markdown]
# ![image.png](attachment:a27afee3-919e-489b-ba36-7672943e3fb0.png)

# %% [markdown]
# ![image.png](attachment:faefbfad-0f74-42d6-b545-0ba5983e0eb7.png)

# %%
# y = aX + b
# y = β₀ + β1
# plane, Hyper-plane
# y = ax + b

from sklearn.linear_model import LinearRegression

X = np.array([
   # area, rooms, age, dist
    [70, 3, 15, 5],
    [90, 4, 10, 7],
    [60, 2, 20, 3],
    [120, 5, 5, 10],
    [80, 3, 12, 6],
    [110, 4, 8, 8],
    [100, 4, 7, 5],
    [75, 3, 18, 4],
    [95, 4, 9, 6],
    [130, 5, 3, 12]
])
Y = np.array([1200, 1500, 1100, 1800, 1300, 1650, 1750, 1250, 1550, 1900])

# Fit the model
model = LinearRegression()
model.fit(X, Y)

# Get coefficients
print(f"Intercept (β₀): {model.intercept_:.2f}")
print(f"Coefficients (β₁, β₂, β₃, β₄): {model.coef_}")

print(model.score(X, Y))

Y_pred_hat = model.predict(X)
Yi_observation = Y

print()

from sklearn.metrics import mean_squared_error, r2_score
print('mse == ', mean_squared_error(Yi_observation, Y_pred_hat))
print('r2_score == ', r2_score(Yi_observation, Y_pred_hat))
# Out:
# Intercept (β₀): 740.66
# Coefficients (β₁, β₂, β₃, β₄): [ 11.31108062  40.10949007 -15.69124359 -41.37800678]
# 0.9878377506382762
#
# mse ==  839.1952059589473
# r2_score ==  0.9878377506382762

# %% [markdown]
# ![image.png](attachment:ddceb81d-73c5-49cf-b9f4-bc69391053b0.png)

# %%
from sklearn.linear_model import LinearRegression

X = np.array([
   # area, rooms, age, dist
    [70, 3, 15, 5],
    [90, 4, 10, 7],
    [60, 2, 20, 3],
    [120, 5, 5, 10],
    [80, 3, 12, 6],
    [110, 4, 8, 8],
    [100, 4, 7, 5],
    [75, 3, 18, 4],
    [95, 4, 9, 6],
    [130, 5, 3, 12]
])
Y = np.array([1200, 1500, 1100, 1800, 1300, 1650, 1750, 1250, 1550, 1900])

# Fit the model
model = LinearRegression()

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 42)

# Get coefficients
print("========== Train")
model.fit(X_train, Y_train)
print(f"Intercept (β₀): {model.intercept_:.2f}")
print(f"Coefficients (β₁, β₂, β₃, β₄): {model.coef_}")

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
train_r2 = r2_score(Y_train, y_pred_train)
print(train_r2)
print(model.score(X_train, Y_train))

print("========== Test")
test_r2 = r2_score(Y_test, y_pred_test)
print(test_r2)
print(model.score(X_test, Y_test))

print()
print("========== All")
model.fit(X, Y)

# Get coefficients
print(f"Intercept (β₀): {model.intercept_:.2f}")
print(f"Coefficients (β₁, β₂, β₃, β₄): {model.coef_}")

print(model.score(X, Y))
# Out:
# ========== Train
# Intercept (β₀): 728.62
# Coefficients (β₁, β₂, β₃, β₄): [ 12.16596537  32.17562254 -16.03435193 -46.5027247 ]
# 0.9912232864474665
# 0.9912232864474665
# ========== Test
# -1.16822476119001
# -1.16822476119001
#
# ========== All
# Intercept (β₀): 740.66
# Coefficients (β₁, β₂, β₃, β₄): [ 11.31108062  40.10949007 -15.69124359 -41.37800678]
# 0.9878377506382762
